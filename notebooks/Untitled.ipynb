# %%
# Out:
# /Users/oscargarcia/Desktop/ADMFinal

# %%
# Out:
# 506 506 506

# %%
# Out:
#      ID  isFreq  isVar  clickNum         time timePeriod  isCorrect  \
# 0     1       0      0         0     6.914680    Initial       True
# 1     1       0      0         1    65.600128    Initial      False
# 2     1       0      0         2    65.975278    Initial       True
# 3     1       0      0         3   100.076446    Initial       True
# 4     1       0      0         4   177.509433  Condition       True
# 5     1       0      0         5   325.754619  Condition       True
# 6     1       0      0         6   448.609708  Condition       True
# 7     1       0      0         7   653.722331  Condition       True
# 8     1       0      0         8   926.884322  Condition       True
# 9     1       0      0         9  1040.306995        End       True
# 10    1       0      0        10  1087.298602        End       True
# 11    1       0      0        11  1165.220337        End       True
# 12    2       0      0         2    64.485920    Initial       True
# ...
